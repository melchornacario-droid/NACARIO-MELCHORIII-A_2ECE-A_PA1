# %% [markdown]
# # ECE 2112: Experiment 1
# **Name:** Nacario Melchor III A
# **Section:** 2ECE-A

# %% [markdown]
# ## Problem A: Word Rotation Problem

# %%
def rotate_word(text):
    new_word=text[1:] + text[0]
    return new_word
print(rotate_word("python")) 
print(rotate_word("logic")) 
print(rotate_word("Code")) 
print(rotate_word("A"))
# Out:
# ythonp
# ogicl
# odeC
# A

# %% [markdown]
# ## Problem B: Username Builder Problem

# %%
def make_username(first_name, last_name):
    n=first_name.lower().replace(" ","")
    m=last_name.lower().replace(" ","")
    user=[n,m]
    return ".".join(user)
print(make_username("Ada", "Lovelace"))     
print(make_username("Alan", "Turing"))        
print(make_username("Ana Maria", "De Leon"))
# Out:
# ada.lovelace
# alan.turing
# anamaria.deleon

# %% [markdown]
# ## Problem C: Bookend Swap Problem

# %%
def swap_bookends(items):
    first, *middle, last = items

    return [last, *middle, first]
print(swap_bookends([1, 2, 3, 4, 5, 6]))  
print(swap_bookends(["red", "green", "blue"])) 
print(swap_bookends([8, 3]))
# Out:
# Enter Items Separated by Spaces:  1 2 3 4 5 6
# ['6', '2', '3', '4', '5', '1']
